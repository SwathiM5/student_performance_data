# %% [markdown]
# ### 1.Use pd.read_csv() (or the appropriate Pandas reader) to bring your file into a DataFrame.

# %%
import pandas as pd

std_per_dt = pd.read_csv(r"C:\Users\HMLAP01\Projects\student_performance_data\data\student_performance_data.csv")

# %% [markdown]
# ### 2.preview the first few rows

# %%
std_per_dt.head(10)
# Out:
#    student_id  gender  study_hours_per_day  attendance_percentage  \
# 0      100000    Male                 4.54                  69.98
# 1      100001  Female                 5.26                  84.80
# 2      100002    Male                 8.69                  73.76
# 3      100003    Male                 4.06                  45.00
# 4      100004    Male                 8.83                  51.13
# 5      100005  Female                 1.79                  53.16
# 6      100006    Male                 7.99                  55.47
# 7      100007    Male                 8.63                  73.92
# 8      100008    Male                 2.64                  70.24
# 9      100009  Female                 4.87                  52.19
#
#    assignment_score  midterm_score  final_exam_score  participation_score  \
# 0             36.47          70.70             53.10                17.96
# 1             34.25          27.92             87.17                11.29
# ...

# %% [markdown]
# ### 3. check data types and missing values

# %%
std_per_dt.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             10000 non-null  int64
#  1   gender                 10000 non-null  str
#  2   study_hours_per_day    10000 non-null  float64
#  3   attendance_percentage  10000 non-null  float64
#  4   assignment_score       10000 non-null  float64
#  5   midterm_score          10000 non-null  float64
#  6   final_exam_score       10000 non-null  float64
#  7   participation_score    10000 non-null  float64
#  8   internet_access        10000 non-null  str
#  9   extra_classes          10000 non-null  str
#  10  parent_education       10000 non-null  str
#  11  sleep_hours            10000 non-null  float64
#  12  overall_score          10000 non-null  float64
#  13  grade                  10000 non-null  str
# dtypes: float64(8), int64(1), str(5)
# ...

# %% [markdown]
# ### 4.see the dimensions of your dataset

# %%
std_per_dt.shape
# Out:
# (10000, 14)

# %% [markdown]
# ### 5.For categorical variables

# %%
std_per_dt.value_counts()
# Out:
# student_id  gender  study_hours_per_day  attendance_percentage  assignment_score  midterm_score  final_exam_score  participation_score  internet_access  extra_classes  parent_education  sleep_hours  final_score  grade
# 100000      Male    4.54                 69.98                  36.47             70.70          53.10             17.96                Yes              No             Master            8.09         52.3480      D        1
# 100001      Female  5.26                 84.80                  34.25             27.92          87.17             11.29                No               Yes            Bachelor          4.73         53.9485      D        1
# 100002      Male    8.69                 73.76                  72.29             70.92          99.61             76.10                No               Yes            PhD               8.73         82.0375      B        1
# ...

# %% [markdown]
# ### 6. For numerical columns

# %%
std_per_dt.describe()
# Out:
#          student_id  study_hours_per_day  attendance_percentage  \
# count   10000.00000         10000.000000           10000.000000
# mean   104999.50000             5.467825              70.493817
# std      2886.89568             2.594134              17.295607
# min    100000.00000             1.000000              40.000000
# 25%    102499.75000             3.220000              55.640000
# 50%    104999.50000             5.420000              70.780000
# 75%    107499.25000             7.740000              85.200000
# max    109999.00000            10.000000             100.000000
#
#        assignment_score  midterm_score  final_exam_score  participation_score  \
# count      10000.000000   10000.000000      10000.000000         10000.000000
# mean          64.717809      62.322568         64.979987            55.103202
# std           20.052779      21.710555         20.216141            25.955949
# ...

# %%
std_per_dt.columns
# Out:
# Index(['student_id', 'gender', 'study_hours_per_day', 'attendance_percentage',
#        'assignment_score', 'midterm_score', 'final_exam_score',
#        'participation_score', 'internet_access', 'extra_classes',
#        'parent_education', 'sleep_hours', 'final_score', 'grade'],
#       dtype='str')

# %% [markdown]
# ### 7.Boolean Indexing

# %%
std_per_dt[std_per_dt["final_score"] > 50]
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 0         100000    Male                 4.54                  69.98
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 3         100003    Male                 4.06                  45.00
# 4         100004    Male                 8.83                  51.13
# ...          ...     ...                  ...                    ...
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
std_per_dt[(std_per_dt["final_score"] > 50) & (std_per_dt["gender"] == "Female")]
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 1         100001  Female                 5.26                  84.80
# 5         100005  Female                 1.79                  53.16
# 9         100009  Female                 4.87                  52.19
# 16        100016  Female                 1.37                  70.69
# 17        100017  Female                 3.90                  82.40
# ...          ...     ...                  ...                    ...
# 9993      109993  Female                 4.59                  51.37
# 9994      109994  Female                 7.82                  42.91
# 9995      109995  Female                 6.86                  59.65
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
std_per_dt[std_per_dt["study_hours_per_day"] > 5]
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 4         100004    Male                 8.83                  51.13
# 6         100006    Male                 7.99                  55.47
# 7         100007    Male                 8.63                  73.92
# ...          ...     ...                  ...                    ...
# 9990      109990  Female                 9.45                  72.21
# 9991      109991  Female                 6.22                  52.90
# 9994      109994  Female                 7.82                  42.91
# 9995      109995  Female                 6.86                  59.65
# 9998      109998  Female                 7.15                  78.24
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
std_per_dt.loc[std_per_dt["final_score"] > 50, ["student_id", "final_score", "grade"]]
# Out:
#       student_id  final_score grade
# 0         100000      52.3480     D
# 1         100001      53.9485     D
# 2         100002      82.0375     B
# 3         100003      66.4110     C
# 4         100004      65.6005     C
# ...          ...          ...   ...
# 9995      109995      55.6720     C
# 9996      109996      66.0930     C
# 9997      109997      73.0355     B
# 9998      109998      71.5400     B
# 9999      109999      84.1005     B
#
# [9076 rows x 3 columns]

# %%
std_per_dt.loc[
    (std_per_dt["gender"] == "Female") & (std_per_dt["final_score"] > 80),
    ["student_id", "gender", "final_score"]
]
# Out:
#       student_id  gender  final_score
# 25        100025  Female      80.2770
# 29        100029  Female      81.3020
# 143       100143  Female      82.6940
# 155       100155  Female      82.9825
# 175       100175  Female      84.7030
# ...          ...     ...          ...
# 9893      109893  Female      83.7285
# 9914      109914  Female      83.4215
# 9933      109933  Female      87.1065
# 9937      109937  Female      81.0360
# 9991      109991  Female      90.5805
#
# [293 rows x 3 columns]

# %%
std_per_dt.iloc[0:5]
# Out:
#    student_id  gender  study_hours_per_day  attendance_percentage  \
# 0      100000    Male                 4.54                  69.98
# 1      100001  Female                 5.26                  84.80
# 2      100002    Male                 8.69                  73.76
# 3      100003    Male                 4.06                  45.00
# 4      100004    Male                 8.83                  51.13
#
#    assignment_score  midterm_score  final_exam_score  participation_score  \
# 0             36.47          70.70             53.10                17.96
# 1             34.25          27.92             87.17                11.29
# 2             72.29          70.92             99.61                76.10
# 3             97.63          31.73             88.85                33.55
# 4             65.19          78.28             54.23                88.99
#
#   internet_access extra_classes parent_education  sleep_hours  final_score  \
# ...

# %%
std_per_dt.iloc[9, 2]
# Out:
# np.float64(4.87)

# %% [markdown]
# ### 8.Sort data

# %%
std_per_dt.sort_values("final_score")
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 3179      103179    Male                 1.85                  59.80
# 5963      105963  Female                 4.19                  70.45
# 1302      101302    Male                 5.37                  63.15
# 9183      109183    Male                 4.12                  44.89
# 728       100728    Male                 2.50                  63.59
# ...          ...     ...                  ...                    ...
# 4667      104667  Female                 2.97                  47.49
# 3598      103598  Female                 5.68                  81.95
# 7374      107374  Female                 9.21                  91.41
# 8453      108453    Male                 2.55                  98.61
# 5745      105745    Male                 6.22                  98.96
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
std_per_dt.sort_values("final_score", ascending=False)
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 5745      105745    Male                 6.22                  98.96
# 8453      108453    Male                 2.55                  98.61
# 7374      107374  Female                 9.21                  91.41
# 3598      103598  Female                 5.68                  81.95
# 4667      104667  Female                 2.97                  47.49
# ...          ...     ...                  ...                    ...
# 728       100728    Male                 2.50                  63.59
# 9183      109183    Male                 4.12                  44.89
# 1302      101302    Male                 5.37                  63.15
# 5963      105963  Female                 4.19                  70.45
# 3179      103179    Male                 1.85                  59.80
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
std_per_dt.sort_values(["grade", "final_score"])
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 4490      104490    Male                 5.51                  95.94
# 3882      103882    Male                 1.31                  77.79
# 1354      101354  Female                 9.29                  70.92
# 8451      108451    Male                 6.37                  96.87
# 9545      109545  Female                 4.18                  87.72
# ...          ...     ...                  ...                    ...
# 5436      105436    Male                 3.58                  57.79
# 5205      105205    Male                 2.85                  57.05
# 3390      103390  Female                 6.45                  49.91
# 3135      103135    Male                 1.57                  84.93
# 9973      109973  Female                 2.47                  43.86
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
std_per_dt.sort_values(["grade", "final_score"], ascending=[True, False])
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 5745      105745    Male                 6.22                  98.96
# 8453      108453    Male                 2.55                  98.61
# 7374      107374  Female                 9.21                  91.41
# 3598      103598  Female                 5.68                  81.95
# 4667      104667  Female                 2.97                  47.49
# ...          ...     ...                  ...                    ...
# 728       100728    Male                 2.50                  63.59
# 9183      109183    Male                 4.12                  44.89
# 1302      101302    Male                 5.37                  63.15
# 5963      105963  Female                 4.19                  70.45
# 3179      103179    Male                 1.85                  59.80
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
std_per_dt.sort_values("study_hours_per_day", ascending=False)
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 9970      109970  Female                10.00                  55.23
# 4927      104927  Female                10.00                  55.73
# 1123      101123    Male                10.00                  62.62
# 5949      105949    Male                10.00                  57.34
# 6472      106472    Male                 9.99                  78.92
# ...          ...     ...                  ...                    ...
# 3506      103506  Female                 1.00                  72.89
# 2263      102263  Female                 1.00                  63.21
# 6883      106883    Male                 1.00                  77.64
# 4907      104907    Male                 1.00                  82.39
# 3125      103125  Female                 1.00                  50.90
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
std_per_dt = std_per_dt.sort_values("final_score", ascending=False)

# %%
std_per_dt.sort_values("final_score", ascending=False).head(10)
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 5745      105745    Male                 6.22                  98.96
# 8453      108453    Male                 2.55                  98.61
# 7374      107374  Female                 9.21                  91.41
# 3598      103598  Female                 5.68                  81.95
# 4667      104667  Female                 2.97                  47.49
# 12        100012    Male                 5.82                  99.06
# 7472      107472  Female                 3.63                  91.97
# 7667      107667    Male                 7.83                  92.88
# 8563      108563  Female                 6.01                  94.83
# 2135      102135    Male                 7.65                  97.13
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# 5745             96.15          99.64             97.79                86.17
# ...

# %% [markdown]
# ### 9.Renaming

# %%
std_per_dt.rename(columns={"overall_score": "final_score"}, inplace=True)

# %%
std_per_dt
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 0         100000    Male                 4.54                  69.98
# 1         100001  Female                 5.26                  84.80
# 2         100002    Male                 8.69                  73.76
# 3         100003    Male                 4.06                  45.00
# 4         100004    Male                 8.83                  51.13
# ...          ...     ...                  ...                    ...
# 9995      109995  Female                 6.86                  59.65
# 9996      109996    Male                 2.60                  83.62
# 9997      109997  Female                 1.46                  95.40
# 9998      109998  Female                 7.15                  78.24
# 9999      109999    Male                 3.26                  97.11
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %% [markdown]
# ###10. Droing column

# %%
std_per_dt.drop("student_id", axis=1)
# Out:
#       gender  study_hours_per_day  attendance_percentage  assignment_score  \
# 5745    Male                 6.22                  98.96             96.15
# 8453    Male                 2.55                  98.61             88.66
# 7374  Female                 9.21                  91.41             95.03
# 3598  Female                 5.68                  81.95             90.56
# 4667  Female                 2.97                  47.49             97.74
# ...      ...                  ...                    ...               ...
# 728     Male                 2.50                  63.59             38.72
# 9183    Male                 4.12                  44.89             53.05
# 1302    Male                 5.37                  63.15             31.63
# 5963  Female                 4.19                  70.45             33.97
# 3179    Male                 1.85                  59.80             30.78
#
# ...

# %%
std_per_dt.drop(["student_id", "grade"], axis=1)
# Out:
#       gender  study_hours_per_day  attendance_percentage  assignment_score  \
# 5745    Male                 6.22                  98.96             96.15
# 8453    Male                 2.55                  98.61             88.66
# 7374  Female                 9.21                  91.41             95.03
# 3598  Female                 5.68                  81.95             90.56
# 4667  Female                 2.97                  47.49             97.74
# ...      ...                  ...                    ...               ...
# 728     Male                 2.50                  63.59             38.72
# 9183    Male                 4.12                  44.89             53.05
# 1302    Male                 5.37                  63.15             31.63
# 5963  Female                 4.19                  70.45             33.97
# 3179    Male                 1.85                  59.80             30.78
#
# ...

# %% [markdown]
# ### 11. Checking data types

# %%
std_per_dt.dtypes
# Out:
# student_id                 int64
# gender                       str
# study_hours_per_day      float64
# attendance_percentage    float64
# assignment_score         float64
# midterm_score            float64
# final_exam_score         float64
# participation_score      float64
# internet_access              str
# extra_classes                str
# parent_education             str
# sleep_hours              float64
# final_score              float64
# grade                        str
# dtype: object

# %%
std_per_dt.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             10000 non-null  int64
#  1   gender                 10000 non-null  str
#  2   study_hours_per_day    10000 non-null  float64
#  3   attendance_percentage  10000 non-null  float64
#  4   assignment_score       10000 non-null  float64
#  5   midterm_score          10000 non-null  float64
#  6   final_exam_score       10000 non-null  float64
#  7   participation_score    10000 non-null  float64
#  8   internet_access        10000 non-null  str
#  9   extra_classes          10000 non-null  str
#  10  parent_education       10000 non-null  str
#  11  sleep_hours            10000 non-null  float64
#  12  final_score            10000 non-null  float64
#  13  grade                  10000 non-null  str
# dtypes: float64(8), int64(1), str(5)
# ...

# %%
std_per_dt["study_hours_per_day"] = pd.to_numeric(
    std_per_dt["study_hours_per_day"],
    errors="coerce"
)

# %%
std_per_dt.columns
# Out:
# Index(['student_id', 'gender', 'study_hours_per_day', 'attendance_percentage',
#        'assignment_score', 'midterm_score', 'final_exam_score',
#        'participation_score', 'internet_access', 'extra_classes',
#        'parent_education', 'sleep_hours', 'final_score', 'grade'],
#       dtype='str')

# %% [markdown]
# ### 12. Identifying missing values

# %%
std_per_dt.isna()
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 5745       False   False                False                  False
# 8453       False   False                False                  False
# 7374       False   False                False                  False
# 3598       False   False                False                  False
# 4667       False   False                False                  False
# ...          ...     ...                  ...                    ...
# 728        False   False                False                  False
# 9183       False   False                False                  False
# 1302       False   False                False                  False
# 5963       False   False                False                  False
# 3179       False   False                False                  False
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
std_per_dt.isnull()
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 5745       False   False                False                  False
# 8453       False   False                False                  False
# 7374       False   False                False                  False
# 3598       False   False                False                  False
# 4667       False   False                False                  False
# ...          ...     ...                  ...                    ...
# 728        False   False                False                  False
# 9183       False   False                False                  False
# 1302       False   False                False                  False
# 5963       False   False                False                  False
# 3179       False   False                False                  False
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %%
std_per_dt.isna().sum()
# Out:
# student_id               0
# gender                   0
# study_hours_per_day      0
# attendance_percentage    0
# assignment_score         0
# midterm_score            0
# final_exam_score         0
# participation_score      0
# internet_access          0
# extra_classes            0
# parent_education         0
# sleep_hours              0
# final_score              0
# grade                    0
# dtype: int64

# %%
# Any row containing NaN
std_per_dt[std_per_dt.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [student_id, gender, study_hours_per_day, attendance_percentage, assignment_score, midterm_score, final_exam_score, participation_score, internet_access, extra_classes, parent_education, sleep_hours, final_score, grade]
# Index: []

# %%
#checking specific column
std_per_dt["final_score"].isna()
# Out:
# 5745    False
# 8453    False
# 7374    False
# 3598    False
# 4667    False
#         ...
# 728     False
# 9183    False
# 1302    False
# 5963    False
# 3179    False
# Name: final_score, Length: 10000, dtype: bool

# %%
#show rows with missing data
std_per_dt[std_per_dt.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [student_id, gender, study_hours_per_day, attendance_percentage, assignment_score, midterm_score, final_exam_score, participation_score, internet_access, extra_classes, parent_education, sleep_hours, final_score, grade]
# Index: []

# %% [markdown]
# ### 13. Identifying and removing duplicates

# %%
# Finding duplicate rows
std_per_dt.duplicated()
# Out:
# 5745    False
# 8453    False
# 7374    False
# 3598    False
# 4667    False
#         ...
# 728     False
# 9183    False
# 1302    False
# 5963    False
# 3179    False
# Length: 10000, dtype: bool

# %%
# view total no.of duplicate rows
std_per_dt.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Droping duplicate rows, not necessary this but just run this for my future reference to understand how to drop duplicates.
std_per_dt.drop_duplicates()
# Out:
#       student_id  gender  study_hours_per_day  attendance_percentage  \
# 5745      105745    Male                 6.22                  98.96
# 8453      108453    Male                 2.55                  98.61
# 7374      107374  Female                 9.21                  91.41
# 3598      103598  Female                 5.68                  81.95
# 4667      104667  Female                 2.97                  47.49
# ...          ...     ...                  ...                    ...
# 728       100728    Male                 2.50                  63.59
# 9183      109183    Male                 4.12                  44.89
# 1302      101302    Male                 5.37                  63.15
# 5963      105963  Female                 4.19                  70.45
# 3179      103179    Male                 1.85                  59.80
#
#       assignment_score  midterm_score  final_exam_score  participation_score  \
# ...

# %% [markdown]
# ### 14. Count values in a column

# %%
std_per_dt["gender"].value_counts()
# Out:
# gender
# Male      5013
# Female    4987
# Name: count, dtype: int64

# %%
# count with missing values included
std_per_dt["gender"].value_counts(dropna=False)
# Out:
# gender
# Male      5013
# Female    4987
# Name: count, dtype: int64

# %%
std_per_dt["grade"].value_counts() #categorical variables or qualitative variable.
# Out:
# grade
# C    5073
# B    2704
# D    2008
# A     154
# F      61
# Name: count, dtype: int64

# %% [markdown]
# ### 15.Summary of  all numerical values

# %%
std_per_dt.describe() # Quantitative variables
# Out:
#          student_id  study_hours_per_day  attendance_percentage  \
# count   10000.00000         10000.000000           10000.000000
# mean   104999.50000             5.467825              70.493817
# std      2886.89568             2.594134              17.295607
# min    100000.00000             1.000000              40.000000
# 25%    102499.75000             3.220000              55.640000
# 50%    104999.50000             5.420000              70.780000
# 75%    107499.25000             7.740000              85.200000
# max    109999.00000            10.000000             100.000000
#
#        assignment_score  midterm_score  final_exam_score  participation_score  \
# count      10000.000000   10000.000000      10000.000000         10000.000000
# mean          64.717809      62.322568         64.979987            55.103202
# std           20.052779      21.710555         20.216141            25.955949
# ...

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ----------------- ---------------------- 3.7/8.3 MB 22.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 21.8 MB/s  0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 45.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 7.2/7.2 MB 36.9 MB/s  0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
# ...

# %%
std_per_dt['study_hours_per_day'].hist()

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Setting Lines thinner:
for spine in ax.spines.values():
    spine.set_linewidth(0.25)
    spine.set_alpha(0.5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(std_per_dt['final_score'], kde=True)
plt.title("Distribution of Overall Score")

#Setting Lines thinner:
for spine in ax.spines.values():
    spine.set_linewidth(0.25)
    spine.set_alpha(0.5)

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Setting Lines thinner:
for spine in ax.spines.values():
    spine.set_linewidth(0.25)
    spine.set_alpha(0.5)

plt.show()

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: C:\Users\HMLAP01\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

sns.boxplot(x=std_per_dt["study_hours_per_day"])
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
std_per_dt.columns
# Out:
# Index(['student_id', 'gender', 'study_hours_per_day', 'attendance_percentage',
#        'assignment_score', 'midterm_score', 'final_exam_score',
#        'participation_score', 'internet_access', 'extra_classes',
#        'parent_education', 'sleep_hours', 'final_score', 'grade'],
#       dtype='str')

# %%
std_per_dt.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             10000 non-null  int64
#  1   gender                 10000 non-null  str
#  2   study_hours_per_day    10000 non-null  float64
#  3   attendance_percentage  10000 non-null  float64
#  4   assignment_score       10000 non-null  float64
#  5   midterm_score          10000 non-null  float64
#  6   final_exam_score       10000 non-null  float64
#  7   participation_score    10000 non-null  float64
#  8   internet_access        10000 non-null  str
#  9   extra_classes          10000 non-null  str
#  10  parent_education       10000 non-null  str
#  11  sleep_hours            10000 non-null  float64
#  12  final_score            10000 non-null  float64
#  13  grade                  10000 non-null  str
# dtypes: float64(8), int64(1), str(5)
# ...

# %%
std_per_dt_corr = std_per_dt[['student_id', 'study_hours_per_day', 'attendance_percentage',
       'assignment_score', 'midterm_score', 'final_exam_score',
       'participation_score', 'sleep_hours', 'final_score']].corr()
std_per_dt_corr
# Out:
#                        student_id  study_hours_per_day  attendance_percentage  \
# student_id               1.000000             0.011394               0.002863
# study_hours_per_day      0.011394             1.000000              -0.014053
# attendance_percentage    0.002863            -0.014053               1.000000
# assignment_score         0.009638            -0.011162              -0.018467
# midterm_score           -0.000074             0.011053              -0.020809
# final_exam_score         0.006413             0.000124              -0.005300
# participation_score     -0.004485            -0.011231               0.006597
# sleep_hours             -0.015926            -0.005728              -0.008273
# final_score              0.007520            -0.003651               0.148781
#
#                        assignment_score  midterm_score  final_exam_score  \
# student_id                     0.009638      -0.000074          0.006413
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 6))
sns.heatmap(std_per_dt_corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.barplot(x='gender', y='final_score', data=std_per_dt)
plt.title("Gender vs Overall Score")

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Setting Lines thinner:
for spine in ax.spines.values():
    spine.set_linewidth(0.25)
    spine.set_alpha(0.5)

plt.show()

# %%
sns.barplot(x='parent_education', y='final_score', data=std_per_dt)
plt.title("Parent Education vs Performance")
plt.xticks(rotation=45)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()

# %%
sns.scatterplot(x='study_hours_per_day', y='final_score', data=std_per_dt)
plt.title("Study Hours vs Overall Score")
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()
